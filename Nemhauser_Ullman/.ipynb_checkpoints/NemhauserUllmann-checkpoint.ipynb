# %% [markdown]
# # Nemhauser Ullman Algorithm

# %% [markdown]
# This is an implementation of Nemhauser Ullman algorithm for the knapsack problem.
# This was done as a part of Lecture "Randomized Algorithms and Probabilistic Analysis"
#
# by Prof. Heiko Röglin at University of Bonn (http://www.roeglin.org/)

# %% [markdown]
# # What is a knapsack problem?
# ### Informally:
# A burglar breaks into an appartment and wants to fill the bag (knapsack) to full, but also to gain maximum profit
#
#
# ### Formally:
#
# Given:
#
# - $n$ items, with weights $w$ and profits $p$.
# - knapsack capacity $W$
#
# Find:
#
# - $w_1 x_1 + ... + w_n x_n \leq W$
#
# Maximize:
#
# - $p_1 x_1 + ... + p_n x_n$

# %% [markdown]
# # Exploring an example

# %%
# declare items
names = ['mouse', 'laptop', 'keyboard', 'book', 'pencil', 'cellphone']
weights = [5, 15, 7, 9, 2, 5]
profits = [10, 70, 25, 20, 2, 50]
number_of_items = len(weights)

# %%
print("Total weight is {}".format(sum(weights)))
print("Total profit is {}".format(sum(profits)))
# Out:
# Total weight is 43
# Total profit is 177

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Plot items

# %%
plt.plot(weights, profits, 'ro', label='')
plt.xlabel('weight')
plt.xlabel('profit')
plt.show()

# %% [markdown]
# # Plot profit to weight ratio

# %%
from __future__ import division
profit_weight_relation = sorted([round(w/p, 3) for w, p in zip(weights, profits)])

# %%
plt.plot(profit_weight_relation, 'ro', label='')
plt.ylabel('profit/weight relation')
plt.xlabel('item')
plt.show()

# %% [markdown]
# # Attempt to solve
#
# ### Look at every possible combination of items
#
# For every item from 1 to n, generate a string $\{0,1\}^n$,
# where 0 means we don't pick an item, and 1 means we pick it

# %%
import itertools
solutions = list(itertools.product([0, 1], repeat=number_of_items))

# %%
solution_weights = []
solution_profits = []

for solution in solutions:
    total_profit = 0
    total_weight = 0
    for index, item in enumerate(solution):
        if item:
            total_weight += weights[index]
            total_profit += profits[index]
    solution_weights.append(total_weight)
    solution_profits.append(total_profit)

# %%
plt.plot(solution_weights, solution_profits, 'ro', label='')
plt.xlabel('weights')
plt.ylabel('profits')
plt.show()

# %% [markdown]
# # Nemhauser Ullmann algorithm

# %%
import copy

resultP = []
resultPi = []
P_plus_item = []
P = [(0,0)]

resultP.append(P)

for item in range(number_of_items):
    P_plus_item = copy.deepcopy(P)
    for i, point in enumerate(P_plus_item):
        weight, profit = point
        P_plus_item[i] = tuple((weight + weights[item], profit + profits[item]))
    P = P + P_plus_item
    resultP.append(P)
    resultPi.append(P_plus_item)

# %% [markdown]
# # Plot P and Pi

# %%
f, axarr = plt.subplots(3, 2, figsize=(18, 16))
# Fine-tune figure; make subplots farther from each other.

results_number = -1
for i in range(3):
    for j in range(2):
        results_number += 1
        if results_number < len(resultP):
            x, y = zip(*sorted(resultP[results_number]))
            axarr[i, j].plot(x,y, 'ro', ms=12)
            x, y = zip(*sorted(resultPi[results_number]))
            axarr[i, j].plot(x,y, 'g^', ms=10)
            axarr[i, j].set_title('item' + str(results_number + 1))
            axarr[i, j].set_xlabel('weight')
            axarr[i, j].set_xlabel('profit')

plt.show()
f.subplots_adjust(hspace=0.5)

# %%
f, axarr = plt.subplots(3, 2, figsize=(18, 16))
# Fine-tune figure; make subplots farther from each other.

results_number = -1
for i in range(3):
    for j in range(2):
        results_number += 1
        if results_number < len(resultP):
            x, y = zip(*sorted(resultP[results_number]))
            axarr[i, j].step(x,y, 'ro')
            x, y = zip(*sorted(resultPi[results_number]))
            axarr[i, j].step(x,y, 'g^')
            axarr[i, j].set_title('item' + str(results_number + 1))
            axarr[i, j].set_xlabel('weight')
            axarr[i, j].set_xlabel('profit')

plt.show()
f.subplots_adjust(hspace=0.5)

# %% [markdown]
# Now we need to calculate set Q which is a union of two sets P and Pi
#
# to calculate it we have to remove every dominated solution

# %% [markdown]
# # Calculate set Q = P union Pi (sorted in non-decreasing order)

# %%
f, axarr = plt.subplots(3, 2, figsize=(18, 16))
# Fine-tune figure; make subplots farther from each other.

import itertools

results_number = -1
for i in range(3):
    for j in range(2):
        results_number += 1
        if results_number < len(resultP):
            r = resultP[results_number] + resultPi[results_number]
            x, y = zip(*sorted(r))
            axarr[i, j].step(x,y, 'ro')

plt.show()
f.subplots_adjust(hspace=0.5)

# %%
from heapq import merge
for i in range(len(zip(resultP, resultPi))):
    for a, b in itertools.izip(sorted(resultP[i]), sorted(resultPi[i])):
        weight, profit = b
    print list(merge(sorted(resultP[i]), sorted(resultPi[i])))
    print
# Out:
# [(0, 0), (5, 10)]
#
# [(0, 0), (5, 10), (15, 70), (20, 80)]
#
# [(0, 0), (5, 10), (7, 25), (12, 35), (15, 70), (20, 80), (22, 95), (27, 105)]
#
# [(0, 0), (5, 10), (7, 25), (9, 20), (12, 35), (14, 30), (15, 70), (16, 45), (20, 80), (21, 55), (22, 95), (24, 90), (27, 105), (29, 100), (31, 115), (36, 125)]
#
# [(0, 0), (2, 2), (5, 10), (7, 12), (7, 25), (9, 20), (9, 27), (11, 22), (12, 35), (14, 30), (14, 37), (15, 70), (16, 32), (16, 45), (17, 72), (18, 47), (20, 80), (21, 55), (22, 82), (22, 95), (23, 57), (24, 90), (24, 97), (26, 92), (27, 105), (29, 100), (29, 107), (31, 102), (31, 115), (33, 117), (36, 125), (38, 127)]
#
# [(0, 0), (2, 2), (5, 10), (5, 50), (7, 12), (7, 25), (7, 52), (9, 20), (9, 27), (10, 60), (11, 22), (12, 35), (12, 62), (12, 75), (14, 30), (14, 37), (14, 70), (14, 77), (15, 70), (16, 32), (16, 45), (16, 72), (17, 72), (17, 85), (18, 47), (19, 80), (19, 87), (20, 80), (20, 120), (21, 55), (21, 82), (21, 95), (22, 82), (22, 95), (22, 122), (23, 57), (23, 97), (24, 90), (24, 97), (25, 130), (26, 92), (26, 105), (27, 105), (27, 132), (27, 145), (28, 107), (29, 100), (29, 107), (29, 140), (29, 147), (31, 102), (31, 115), (31, 142), (32, 155), (33, 117), (34, 150), (34, 157), (36, 125), (36, 152), (36, 165), (38, 127), (38, 167), (41, 175), (43, 177)]

# %%
from heapq import merge
